# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("data/processed/cleaned_creditcard.csv")

df["Fraudulent"].value_counts().plot(kind="bar")
plt.title("Fraud vs Non-Fraud Transactions")
plt.xlabel("Fraudulent")
plt.ylabel("Count")
plt.savefig("screenshots/fraud_distribution.png")
plt.show()

# %%
plt.figure(figsize=(8,5))
df["Transaction_Amount"].hist(bins=30)
plt.title("Transaction Amount Distribution")
plt.xlabel("Amount")
plt.ylabel("Frequency")
plt.savefig("screenshots/transaction_amount_histogram.png")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(10,5))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.savefig("screenshots/missing_values_heatmap.png")
plt.show()

# %%
fraud_percent = (
    df["Fraudulent"].sum() / len(df)
) * 100

print(f"Fraud Percentage: {fraud_percent:.2f}%")
